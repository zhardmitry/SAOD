# %% [markdown]
# # Лабораторная работа №1
# ## Выполнил студент группы БСТ1904 Жарков Д. А.
# ### Задание 1
# Создать Jupyter Notebook и вывести надпись "Hello, World!"

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Задание 2
# Написать генератор случайных матриц(многомерных), который принимает опциональные параметры m,n,min_limit,max_limit, где m и n указывают размер матрицы, а min_lim и max_lim - минимальное и максимальное значение для генерируемого числа

# %%
m=50
n=50
min_limit=-250
max_limit=1006

strM=input("\n\nВведите m: ")
if len(strM)>0: m=int(strM)

strN=input("Введите n: ")
if len(strN)>0: n=int(strN)
    
while True:
    strMin_limit=input("Введите минимальное значение: ")
    if len(strMin_limit)>0: min_limit=int(strMin_limit)

    strMax_limit=input("Введите максимальное значение: ")
    if len(strMax_limit)>0: max_limit=int(strMax_limit)
            
    if (min_limit<=max_limit): break
    else: print("\nМинимальный элемент не может быть больше максимального, повторите попытку\n")
# Out:
# Введите m: 50
# Введите n: 50
# Введите минимальное значение: -250
# Введите максимальное значение: 1006

# %%
import random
def randomize(min_limit = -250, max_limit = 1006, n = 50, m = 50):
    arr = [[random.randint(min_limit, max_limit) for i in range(n)],
           [random.randint(min_limit, max_limit) for i in range(m)]]
    return arr

# %% [markdown]
# ### Задание 3
# Реализовать методы сортировки строк числовой матрицы в соответствии с заданием. Оценить время работы каждого алгоритма сортировки и сравнить его со временем стандартной функции сортировки. Испытания проводить на сгенерированных матрицах.

# %% [markdown]
# ### Сортировка выбором

# %%
def SelectionSort(arr):
    array=arr.copy()
    for i in range(len(array)):
        for j in range(len(array[i])-1):
            min=j
            for h in range (j+1,n):
                if (array[i][h]<array[i][min]):
                    min=h
            temp=array[i][j]
            array[i][j]=array[i][min]
            array[i][min]=temp
    return array

# %% [markdown]
# ### Сортировка вставкой

# %%
def InsertionSort(arr):
    array=arr.copy()
    for i in range(len(array)):
        for j in range(len(array[i])):
            temp=array[i][j]
            index=j
            while (temp<array[i][index-1]) and (index>0):
                array[i][index]=array[i][index-1]
                index-=1
            array[i][index]=temp
    return array

# %% [markdown]
# ### Сортировка обменом

# %%
def BubbleSort(arr):
    array=arr.copy()
    for i in range(len(array)):
        for j in range(len(array[i])):
            for h in range(len(array[i])-j-1):
                if(array[i][h+1]<array[i][h]):
                    temp = array[i][h]
                    array[i][h] = array[i][h+1]
                    array[i][h+1] = temp

    return array

# %% [markdown]
# ### Сортировка Шелла

# %%
def ShellSort(arr):
    array=arr.copy()
    for i in range(len(array)):
        d=int(len(array[i])/2)
        while d>0:
            for j in range(len(array[i])):
                for h in range(int(j+d),len(array[i]),d):
                    if array[i][j]>array[i][h]:
                        temp=array[i][j]
                        array[i][j]=array[i][h]
                        array[i][h]=temp
            
            d=int(d/2)
    return array

# %% [markdown]
# ### Сортировка Турнирная

# %%
def TournamentSort(array):
    arr= array.copy()
    for i in range(len(arr)):
        tournamentSort(arr[i])
    return arr
def tournamentSort(arr):
    tree = [None] * 2 * (len(arr) + len(arr) % 2)
    index = len(tree) - len(arr) - len(arr) % 2
    
    for i, v in enumerate(arr):
        tree[index + i] = (i, v)
    
    for j in range(len(arr)):
        n = len(arr)
        index = len(tree) - len(arr) - len(arr) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1) 
                if tree[i] != None and tree[i + 1] != None:
                    if tree[i][1] < tree[i + 1][1]:
                        tree[i // 2] = tree[i]
                    else:
                        tree[i // 2] = tree[i + 1]
                else:
                    tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
            index -= n

        index, x = tree[0]
        arr[j] = x
        tree[len(tree) - len(arr) - len(arr) % 2 + index] = None

# %% [markdown]
# ### Сортировка Быстрая

# %%
def QuickSort(array):
    arr=array.copy()
    for i in range(len(arr)):
        quickSort(0,len(arr[i])-1,arr,i)
    return arr

def quickSort(_first, _last, array, row):
    first=int(_first)
    last=int(_last)
    middle=int((first+last)/2)
    
    while (first<last):
        
        while( array[row][first] < array[row][middle]): 
            first+=1
        while( array[row][last] > array[row][middle]):
            last-=1
        if(first<=last):
            array[row][first],array[row][last]=array[row][last],array[row][first]
            first+=1
            last-=1
    
    if(_first<last):
        quickSort(_first,last,array,row)
    if(first<_last):
        quickSort(first,_last,array,row)

# %% [markdown]
# ### Сортировка Пирамидальная

# %%
def heapify(arr, n, i):
    largest = i
    l = 2 * i + 1
    r = 2 * i + 2

    if l < n and arr[i] < arr[l]:
        largest = l

    if r < n and arr[largest] < arr[r]:
        largest = r

    if largest != i:
        arr[i],arr[largest] = arr[largest],arr[i]

        heapify(arr, n, largest)


def HeapSort(array):
    arr=array.copy()
    for i in range(len(arr)):
        n = len(arr[i])

        for j in range(n, -1, -1):
            heapify(arr[i], n, j)

        for j in range(n-1, 0, -1):
            arr[i][j], arr[i][0] = arr[i][0], arr[i][j] 
            heapify(arr[i], j, 0)
    return arr

# %%
import timeit

print("Сортировка выбором выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
SelectionSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")

print("Сортировка вставкой выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
InsertionSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")

print("Сортировка обменом выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
BubbleSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")

print("Сортировка Шелла выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
ShellSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")

print("Сортировка Турнирная выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
TournamentSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")

print("Сортировка Быстрая выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
QuickSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")

print("Сортировка Пирамидальная выполнилась за ")
arr = randomize(min_limit, max_limit,n , m)
start_time = timeit.default_timer()
HeapSort(arr)
time_2 = timeit.default_timer() - start_time
print(time_2)
print(" секунд")
# Out:
# Сортировка выбором выполнилась за
# 0.0005188211798667908
#  секунд
# Сортировка вставкой выполнилась за
# 0.000514032319188118
#  секунд
# Сортировка обменом выполнилась за
# 0.0009155850857496262
#  секунд
# Сортировка Шелла выполнилась за
# 0.0008446201682090759
#  секунд
# Сортировка Турнирная выполнилась за
# 0.002911122515797615
#  секунд
# Сортировка Быстрая выполнилась за
# 0.00024626776576042175
#  секунд
# Сортировка Пирамидальная выполнилась за
# 0.0003154091536998749
#  секунд
